# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport

# %%
data = pd.read_csv('./data/kickstarter.csv')
data.shape
# Out:
# (1163, 20)

# %% [markdown]
# ## Prepare Data
# * Perform EDA
# * Handle Missing Data (Remove or Impute)
# * Identify Target Data
# * Scale the Data
# * Encode any Text Data (Categorical Data)

# %%
data.head()
# Out:
#   Funded                                                URL  \
# 0     no  https://www.kickstarter.com/projects/mischaa/p...
# 1     no  https://www.kickstarter.com/projects/105587445...
# 2     no  https://www.kickstarter.com/projects/minimalpr...
# 3     no  https://www.kickstarter.com/projects/797661619...
# 4     no  https://www.kickstarter.com/projects/198369359...
#
#                                                Title  Year Month Type  Has FB  \
# 0      Pixelstart: Choose Your Own Pixels (Canceled)  2016   Apr  Art       1
# 1                        Smart shop Icons (Canceled)  2016   Apr  Art       1
# 2  Minimal Haus Prints: Digital Prints for DIY Wa...  2016   Apr  Art       0
# 3          NeoN: Altering the Alternative (Canceled)  2016   Mar  Art       0
# 4          Nintendo NES 8bit retro canvas (Canceled)  2016   Mar  Art       0
#
#    Backed Projects  Previous Projects  Creator Desc Len  Title Len      Goal  \
# 0               11                  2               125         57   2829.59
# 1                0                  0               111         27  28295.87
# 2                4                  0               294         52    766.25
# 3                0                  0               179         41   1439.10
# 4                0                  0                51         41   1000.00
#
#    Duration  Pledge Levels  Min Pledge Tiers  Max Pledge Tiers  Proj Desc Len  \
# 0        53              7              1.14             171.0           2001
# 1        51              3              1.14              46.0           2508
# 2        30              8              1.51             755.0           2325
# 3        24              5              7.00             141.0           3736
# 4        30              2              5.00              20.0            636
#
#    Images  Videos  Has Video
# 0       2       1          1
# 1       0       0          0
# 2       1       1          1
# 3      13       1          1
# 4       0       0          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1163 entries, 0 to 1162
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Funded             1163 non-null   object
#  1   URL                1163 non-null   object
#  2   Title              1163 non-null   object
#  3   Year               1163 non-null   int64
#  4   Month              1163 non-null   object
#  5   Type               1163 non-null   object
#  6   Has FB             1163 non-null   int64
#  7   Backed Projects    1163 non-null   int64
#  8   Previous Projects  1163 non-null   int64
#  9   Creator Desc Len   1163 non-null   int64
#  10  Title Len          1163 non-null   int64
#  11  Goal               1163 non-null   float64
#  12  Duration           1163 non-null   int64
#  13  Pledge Levels      1163 non-null   int64
#  14  Min Pledge Tiers   1163 non-null   float64
#  15  Max Pledge Tiers   1163 non-null   float64
#  16  Proj Desc Len      1163 non-null   int64
#  17  Images             1163 non-null   int64
#  18  Videos             1163 non-null   int64
#  19  Has Video          1163 non-null   int64
# dtypes: float64(3), int64(12), object(5)
# memory usage: 181.8+ KB

# %%
data.isnull().sum()
# Out:
# Funded               0
# URL                  0
# Title                0
# Year                 0
# Month                0
# Type                 0
# Has FB               0
# Backed Projects      0
# Previous Projects    0
# Creator Desc Len     0
# Title Len            0
# Goal                 0
# Duration             0
# Pledge Levels        0
# Min Pledge Tiers     0
# Max Pledge Tiers     0
# Proj Desc Len        0
# Images               0
# Videos               0
# Has Video            0
# dtype: int64

# %%
data['Funded'].value_counts()
# Out:
# Funded
# no     685
# yes    478
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Funded', 'URL', 'Title', 'Year', 'Month', 'Type', 'Has FB',
#        'Backed Projects', 'Previous Projects', 'Creator Desc Len', 'Title Len',
#        'Goal', 'Duration', 'Pledge Levels', 'Min Pledge Tiers',
#        'Max Pledge Tiers', 'Proj Desc Len', 'Images', 'Videos', 'Has Video'],
#       dtype='object')

# %%
# PERFORM ANY RENAMES...       we rename by copying columns and saving them back
#df.columns = [' ',....]

# %%
#ProfileReport(data, title ='Kickstarter')

# %% [raw]
# kickstarter = ProfileReport(data, title ='KickstarterEDA')
# kickstarter.to_file('./eda/Kickstarter.html')

# %% [markdown]
# ### Create a classifier:
# * Using the kickstarter.csv file for train and test
# * Using the unseen_data.csv below for a final test
# * 'Funded' is the feature I will predict
# ### Classifier Steps
# 1) Gather sample data for "unseen data"
#     * a. create a train / test csv file
#     * b. create a unseen data csv file
# 2) Pycaret EDA notebook
#     * a. identify the best (sklearn) model
#        * i. using the train / test csv from step 1
#     * b. EDA
# 3) Lean Pycaret notebook:
#     * create the model
#     * export the pipline (i.e. finalize model)
# 4) Import using joblib
#     * run against unseen data
#     * test results

# %% [markdown]
# #### **1.**  First I set aside 20% of data sample to be used in the end against the trined and tested data and i save them each in .csv file

# %%
unseen_data = data.sample(frac=.20)   # set asides data.sample(frac=.30, random_state=42) , i decided for 20% 
df = data.drop(unseen_data.index)

# %%
# does my row count match
data.shape[0] == df.shape[0] + unseen_data.shape[0]
# Out:
# True

# %%
#unseen_data.to_csv('./data/unseen_data.csv')
#reset the index
unseen_data.to_csv('./data/unseen_data.csv', index=False)

# %%
#df.to_csv('./data/adult_census.csv')
#reset index
df.to_csv('./data/Kickstarter0.8.csv', index=False)

# %%
df.describe().T
# Out:
#                    count          mean            std      min       25%  \
# Year               930.0   2016.000000       0.000000  2016.00  2016.000
# Has FB             930.0      0.516129       0.500009     0.00     0.000
# Backed Projects    930.0      4.208602      16.546751     0.00     0.000
# Previous Projects  930.0      0.866667       2.574084     0.00     0.000
# Creator Desc Len   930.0    358.488172     168.425254     0.00   215.000
# Title Len          930.0     36.419355      17.890724     1.00    20.000
# Goal               930.0  40767.897000  338342.594066    15.32  1936.715
# Duration           930.0     33.593548      11.461470     4.00    30.000
# Pledge Levels      930.0      7.168817       5.985855     1.00     3.000
# Min Pledge Tiers   930.0     40.875527     415.250747     0.70     1.130
# Max Pledge Tiers   930.0   1404.354720    2579.419464     0.76    78.000
# Proj Desc Len      930.0   4148.737634    3843.914257    59.00  1527.250
# Images             930.0      7.860215      12.369440     0.00     0.000
# Videos             930.0      0.818280       0.978944     0.00     0.000
# Has Video          930.0      0.659140       0.474253     0.00     0.000
#
#                       50%       75%         max
# Year               2016.0   2016.00      2016.0
# Has FB                1.0      1.00         1.0
# Backed Projects       0.0      2.00       348.0
# Previous Projects     0.0      0.00        29.0
# Creator Desc Len    398.0    504.00       747.0
# Title Len            37.0     53.00        82.0
# Goal               7000.0  22636.70  10000000.0
# Duration             30.0     35.00        62.0
# Pledge Levels         6.0     10.00        89.0
# Min Pledge Tiers      5.0     14.00     10000.0
# Max Pledge Tiers    300.0   1000.75     25000.0
# Proj Desc Len      2956.5   5576.25     28293.0
# Images                3.0     10.00        95.0
# Videos                1.0      1.00        13.0
# Has Video             1.0      1.00         1.0

# %%
df.columns
# Out:
# Index(['Funded', 'URL', 'Title', 'Year', 'Month', 'Type', 'Has FB',
#        'Backed Projects', 'Previous Projects', 'Creator Desc Len', 'Title Len',
#        'Goal', 'Duration', 'Pledge Levels', 'Min Pledge Tiers',
#        'Max Pledge Tiers', 'Proj Desc Len', 'Images', 'Videos', 'Has Video'],
#       dtype='object')

# %% [markdown]
# #### **2.** Second, we import Classification Experiment and/or classification models and set up the Target + select best model

# %%
#pip install --upgrade joblib
# !pip install joblib==1.3.0

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()

# %%
s.setup(data, target = 'Funded', session_id = 42)       #quickstart has 123, we do 42
# Out:
# <style type="text/css">
# #T_46a3b_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_46a3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46a3b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_46a3b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46a3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46a3b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_46a3b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46a3b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_46a3b_row1_col1" class="data row1 col1" >Funded</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46a3b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_46a3b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46a3b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_46a3b_row3_col1" class="data row3 col1" >no: 0, yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46a3b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_46a3b_row4_col1" class="data row4 col1" >(1163, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46a3b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_46a3b_row5_col1" class="data row5 col1" >(1163, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_46a3b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_46a3b_row6_col1" class="data row6 col1" >(814, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_46a3b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_46a3b_row7_col1" class="data row7 col1" >(349, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_46a3b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_46a3b_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_46a3b_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_46a3b_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_46a3b_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_46a3b_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_46a3b_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_46a3b_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_46a3b_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_46a3b_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_46a3b_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_46a3b_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_46a3b_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_46a3b_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_46a3b_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_46a3b_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_46a3b_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_46a3b_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_46a3b_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_46a3b_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_46a3b_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_46a3b_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_46a3b_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_46a3b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_46a3b_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_46a3b_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_46a3b_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_46a3b_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_46a3b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_46a3b_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_46a3b_row22_col1" class="data row22 col1" >76cc</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%time
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_1e57c th {
#   text-align: left;
# }
# #T_1e57c_row0_col0, #T_1e57c_row0_col4, #T_1e57c_row1_col0, #T_1e57c_row1_col1, #T_1e57c_row1_col3, #T_1e57c_row1_col5, #T_1e57c_row1_col6, #T_1e57c_row1_col7, #T_1e57c_row2_col0, #T_1e57c_row2_col1, #T_1e57c_row2_col3, #T_1e57c_row2_col4, #T_1e57c_row2_col5, #T_1e57c_row2_col6, #T_1e57c_row2_col7, #T_1e57c_row3_col0, #T_1e57c_row3_col1, #T_1e57c_row3_col3, #T_1e57c_row3_col4, #T_1e57c_row3_col5, #T_1e57c_row3_col6, #T_1e57c_row3_col7, #T_1e57c_row4_col0, #T_1e57c_row4_col1, #T_1e57c_row4_col3, #T_1e57c_row4_col4, #T_1e57c_row4_col5, #T_1e57c_row4_col6, #T_1e57c_row4_col7, #T_1e57c_row5_col0, #T_1e57c_row5_col1, #T_1e57c_row5_col3, #T_1e57c_row5_col4, #T_1e57c_row5_col5, #T_1e57c_row5_col6, #T_1e57c_row5_col7, #T_1e57c_row6_col0, #T_1e57c_row6_col1, #T_1e57c_row6_col3, #T_1e57c_row6_col4, #T_1e57c_row6_col5, #T_1e57c_row6_col6, #T_1e57c_row6_col7, #T_1e57c_row7_col0, #T_1e57c_row7_col1, #T_1e57c_row7_col3, #T_1e57c_row7_col4, #T_1e57c_row7_col5, #T_1e57c_row7_col6, #T_1e57c_row7_col7, #T_1e57c_row8_col0, #T_1e57c_row8_col1, #T_1e57c_row8_col3, #T_1e57c_row8_col4, #T_1e57c_row8_col5, #T_1e57c_row8_col6, #T_1e57c_row8_col7, #T_1e57c_row9_col0, #T_1e57c_row9_col1, #T_1e57c_row9_col3, #T_1e57c_row9_col4, #T_1e57c_row9_col5, #T_1e57c_row9_col6, #T_1e57c_row9_col7, #T_1e57c_row10_col0, #T_1e57c_row10_col1, #T_1e57c_row10_col3, #T_1e57c_row10_col4, #T_1e57c_row10_col5, #T_1e57c_row10_col6, #T_1e57c_row10_col7, #T_1e57c_row11_col0, #T_1e57c_row11_col1, #T_1e57c_row11_col3, #T_1e57c_row11_col4, #T_1e57c_row11_col5, #T_1e57c_row11_col6, #T_1e57c_row11_col7, #T_1e57c_row12_col0, #T_1e57c_row12_col1, #T_1e57c_row12_col3, #T_1e57c_row12_col4, #T_1e57c_row12_col5, #T_1e57c_row12_col6, #T_1e57c_row12_col7, #T_1e57c_row13_col0, #T_1e57c_row13_col1, #T_1e57c_row13_col3, #T_1e57c_row13_col4, #T_1e57c_row13_col5, #T_1e57c_row13_col6, #T_1e57c_row13_col7, #T_1e57c_row14_col0, #T_1e57c_row14_col1, #T_1e57c_row14_col3, #T_1e57c_row14_col4, #T_1e57c_row14_col5, #T_1e57c_row14_col6, #T_1e57c_row14_col7 {
#   text-align: left;
# }
# #T_1e57c_row0_col1, #T_1e57c_row0_col2, #T_1e57c_row0_col3, #T_1e57c_row0_col5, #T_1e57c_row0_col6, #T_1e57c_row0_col7, #T_1e57c_row1_col2, #T_1e57c_row1_col4, #T_1e57c_row2_col2, #T_1e57c_row3_col2, #T_1e57c_row4_col2, #T_1e57c_row5_col2, #T_1e57c_row6_col2, #T_1e57c_row7_col2, #T_1e57c_row8_col2, #T_1e57c_row9_col2, #T_1e57c_row10_col2, #T_1e57c_row11_col2, #T_1e57c_row12_col2, #T_1e57c_row13_col2, #T_1e57c_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1e57c_row0_col8, #T_1e57c_row1_col8, #T_1e57c_row3_col8, #T_1e57c_row4_col8, #T_1e57c_row5_col8, #T_1e57c_row6_col8, #T_1e57c_row7_col8, #T_1e57c_row8_col8, #T_1e57c_row9_col8, #T_1e57c_row10_col8, #T_1e57c_row11_col8, #T_1e57c_row12_col8, #T_1e57c_row13_col8, #T_1e57c_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1e57c_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1e57c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e57c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1e57c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1e57c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1e57c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1e57c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1e57c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1e57c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1e57c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1e57c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e57c_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_1e57c_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_1e57c_row0_col1" class="data row0 col1" >0.7801</td>
#       <td id="T_1e57c_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_1e57c_row0_col3" class="data row0 col3" >0.7801</td>
#       <td id="T_1e57c_row0_col4" class="data row0 col4" >0.7794</td>
#       <td id="T_1e57c_row0_col5" class="data row0 col5" >0.7776</td>
#       <td id="T_1e57c_row0_col6" class="data row0 col6" >0.5381</td>
#       <td id="T_1e57c_row0_col7" class="data row0 col7" >0.5413</td>
#       <td id="T_1e57c_row0_col8" class="data row0 col8" >0.6550</td>
#     </tr>
#     <tr>
#       <th id="T_1e57c_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_1e57c_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_1e57c_row1_col1" class="data row1 col1" >0.7298</td>
#       <td id="T_1e57c_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_1e57c_row1_col3" class="data row1 col3" >0.7298</td>
#       <td id="T_1e57c_row1_col4" class="data row1 col4" >0.7879</td>
#       <td id="T_1e57c_row1_col5" class="data row1 col5" >0.6953</td>
#       <td id="T_1e57c_row1_col6" class="data row1 col6" >0.3882</td>
#       <td id="T_1e57c_row1_col7" class="data row1 col7" >0.4654</td>
#       <td id="T_1e57c_row1_col8" class="data row1 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_1e57c_level0_row2" class="row_heading level0 row2" >svm</th>
#       <td id="T_1e57c_row2_col0" class="data row2 col0" >SVM - Linear Kernel</td>
#       <td id="T_1e57c_row2_col1" class="data row2 col1" >0.6671</td>
#       <td id="T_1e57c_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_1e57c_row2_col3" class="data row2 col3" >0.6671</td>
#       <td id="T_1e57c_row2_col4" class="data row2 col4" >0.7161</td>
#       <td id="T_1e57c_row2_col5" class="data row2 col5" >0.6591</td>
#       <td id="T_1e57c_row2_col6" class="data row2 col6" >0.3409</td>
#       <td id="T_1e57c_row2_col7" class="data row2 col7" >0.3741</td>
#       <td id="T_1e57c_row2_col8" class="data row2 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_1e57c_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_1e57c_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_1e57c_row3_col1" class="data row3 col1" >0.6525</td>
#       <td id="T_1e57c_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_1e57c_row3_col3" class="data row3 col3" >0.6525</td>
#       <td id="T_1e57c_row3_col4" class="data row3 col4" >0.6498</td>
#       <td id="T_1e57c_row3_col5" class="data row3 col5" >0.6477</td>
#       <td id="T_1e57c_row3_col6" class="data row3 col6" >0.2709</td>
#       <td id="T_1e57c_row3_col7" class="data row3 col7" >0.2739</td>
#       <td id="T_1e57c_row3_col8" class="data row3 col8" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_1e57c_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_1e57c_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_1e57c_row4_col1" class="data row4 col1" >0.5897</td>
#       <td id="T_1e57c_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_1e57c_row4_col3" class="data row4 col3" >0.5897</td>
#       <td id="T_1e57c_row4_col4" class="data row4 col4" >0.4291</td>
#       <td id="T_1e57c_row4_col5" class="data row4 col5" >0.4409</td>
#       <td id="T_1e57c_row4_col6" class="data row4 col6" >0.0045</td>
#       <td id="T_1e57c_row4_col7" class="data row4 col7" >0.0172</td>
#       <td id="T_1e57c_row4_col8" class="data row4 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_1e57c_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_1e57c_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_1e57c_row5_col1" class="data row5 col1" >0.5885</td>
#       <td id="T_1e57c_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_1e57c_row5_col3" class="data row5 col3" >0.5885</td>
#       <td id="T_1e57c_row5_col4" class="data row5 col4" >0.3463</td>
#       <td id="T_1e57c_row5_col5" class="data row5
# CPU times: total: 4.22 s
# Wall time: 20.9 s

# %%
s.models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
from pycaret.classification import setup, models, create_model, tune_model, finalize_model, save_model

cls = setup(data, target='Funded', session_id=42, fix_imbalance=True);
# Out:
# <style type="text/css">
# #T_384d0_row10_col1, #T_384d0_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_384d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_384d0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_384d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_384d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_384d0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_384d0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_384d0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_384d0_row1_col1" class="data row1 col1" >Funded</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_384d0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_384d0_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_384d0_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_384d0_row3_col1" class="data row3 col1" >no: 0, yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_384d0_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_384d0_row4_col1" class="data row4 col1" >(1163, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_384d0_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_384d0_row5_col1" class="data row5 col1" >(1307, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_384d0_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_384d0_row6_col1" class="data row6 col1" >(958, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_384d0_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_384d0_row7_col1" class="data row7 col1" >(349, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_384d0_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_384d0_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_384d0_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_384d0_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_384d0_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_384d0_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_384d0_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_384d0_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_384d0_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_384d0_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_384d0_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_384d0_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_384d0_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_384d0_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_384d0_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_384d0_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_384d0_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_384d0_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_384d0_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_384d0_row17_col1" class="data row17 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_384d0_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_384d0_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_384d0_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_384d0_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_384d0_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_384d0_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_384d0_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_384d0_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_384d0_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_384d0_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_384d0_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_384d0_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_384d0_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_384d0_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_384d0_row24_col1" class="data row24 col1" >fc70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **3.** Third, we create, tune and finalize the model and export the .pkl file

# %%
lr = s.create_model('lr')
lr
# Out:
# <style type="text/css">
# #T_f01b0_row10_col0, #T_f01b0_row10_col1, #T_f01b0_row10_col2, #T_f01b0_row10_col3, #T_f01b0_row10_col4, #T_f01b0_row10_col5, #T_f01b0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f01b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f01b0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f01b0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f01b0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f01b0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f01b0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f01b0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f01b0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f01b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f01b0_row0_col0" class="data row0 col0" >0.7805</td>
#       <td id="T_f01b0_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_f01b0_row0_col2" class="data row0 col2" >0.7805</td>
#       <td id="T_f01b0_row0_col3" class="data row0 col3" >0.7794</td>
#       <td id="T_f01b0_row0_col4" class="data row0 col4" >0.7780</td>
#       <td id="T_f01b0_row0_col5" class="data row0 col5" >0.5399</td>
#       <td id="T_f01b0_row0_col6" class="data row0 col6" >0.5427</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f01b0_row1_col0" class="data row1 col0" >0.8049</td>
#       <td id="T_f01b0_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_f01b0_row1_col2" class="data row1 col2" >0.8049</td>
#       <td id="T_f01b0_row1_col3" class="data row1 col3" >0.8045</td>
#       <td id="T_f01b0_row1_col4" class="data row1 col4" >0.8027</td>
#       <td id="T_f01b0_row1_col5" class="data row1 col5" >0.5910</td>
#       <td id="T_f01b0_row1_col6" class="data row1 col6" >0.5941</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f01b0_row2_col0" class="data row2 col0" >0.7927</td>
#       <td id="T_f01b0_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_f01b0_row2_col2" class="data row2 col2" >0.7927</td>
#       <td id="T_f01b0_row2_col3" class="data row2 col3" >0.7920</td>
#       <td id="T_f01b0_row2_col4" class="data row2 col4" >0.7922</td>
#       <td id="T_f01b0_row2_col5" class="data row2 col5" >0.5711</td>
#       <td id="T_f01b0_row2_col6" class="data row2 col6" >0.5713</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f01b0_row3_col0" class="data row3 col0" >0.7561</td>
#       <td id="T_f01b0_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_f01b0_row3_col2" class="data row3 col2" >0.7561</td>
#       <td id="T_f01b0_row3_col3" class="data row3 col3" >0.7543</td>
#       <td id="T_f01b0_row3_col4" class="data row3 col4" >0.7534</td>
#       <td id="T_f01b0_row3_col5" class="data row3 col5" >0.4888</td>
#       <td id="T_f01b0_row3_col6" class="data row3 col6" >0.4914</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f01b0_row4_col0" class="data row4 col0" >0.7284</td>
#       <td id="T_f01b0_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_f01b0_row4_col2" class="data row4 col2" >0.7284</td>
#       <td id="T_f01b0_row4_col3" class="data row4 col3" >0.7264</td>
#       <td id="T_f01b0_row4_col4" class="data row4 col4" >0.7269</td>
#       <td id="T_f01b0_row4_col5" class="data row4 col5" >0.4321</td>
#       <td id="T_f01b0_row4_col6" class="data row4 col6" >0.4327</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f01b0_row5_col0" class="data row5 col0" >0.7778</td>
#       <td id="T_f01b0_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_f01b0_row5_col2" class="data row5 col2" >0.7778</td>
#       <td id="T_f01b0_row5_col3" class="data row5 col3" >0.7763</td>
#       <td id="T_f01b0_row5_col4" class="data row5 col4" >0.7766</td>
#       <td id="T_f01b0_row5_col5" class="data row5 col5" >0.5354</td>
#       <td id="T_f01b0_row5_col6" class="data row5 col6" >0.5361</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f01b0_row6_col0" class="data row6 col0" >0.7901</td>
#       <td id="T_f01b0_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_f01b0_row6_col2" class="data row6 col2" >0.7901</td>
#       <td id="T_f01b0_row6_col3" class="data row6 col3" >0.7924</td>
#       <td id="T_f01b0_row6_col4" class="data row6 col4" >0.7848</td>
#       <td id="T_f01b0_row6_col5" class="data row6 col5" >0.5504</td>
#       <td id="T_f01b0_row6_col6" class="data row6 col6" >0.5601</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f01b0_row7_col0" class="data row7 col0" >0.8272</td>
#       <td id="T_f01b0_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_f01b0_row7_col2" class="data row7 col2" >0.8272</td>
#       <td id="T_f01b0_row7_col3" class="data row7 col3" >0.8263</td>
#       <td id="T_f01b0_row7_col4" class="data row7 col4" >0.8262</td>
#       <td id="T_f01b0_row7_col5" class="data row7 col5" >0.6386</td>
#       <td id="T_f01b0_row7_col6" class="data row7 col6" >0.6395</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f01b0_row8_col0" class="data row8 col0" >0.7654</td>
#       <td id="T_f01b0_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_f01b0_row8_col2" class="data row8 col2" >0.7654</td>
#       <td id="T_f01b0_row8_col3" class="data row8 col3" >0.7659</td>
#       <td id="T_f01b0_row8_col4" class="data row8 col4" >0.7595</td>
#       <td id="T_f01b0_row8_col5" class="data row8 col5" >0.4976</td>
#       <td id="T_f01b0_row8_col6" class="data row8 col6" >0.5063</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f01b0_row9_col0" class="data row9 col0" >0.7778</td>
#       <td id="T_f01b0_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_f01b0_row9_col2" class="data row9 col2" >0.7778</td>
#       <td id="T_f01b0_row9_col3" class="data row9 col3" >0.7769</td>
#       <td id="T_f01b0_row9_col4" class="data row9 col4" >0.7754</td>
#       <td id="T_f01b0_row9_col5" class="data row9 col5" >0.5363</td>
#       <td id="T_f01b0_row9_col6" class="data row9 col6" >0.5391</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f01b0_row10_col0" class="data row10 col0" >0.7801</td>
#       <td id="T_f01b0_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_f01b0_row10_col2" class="data row10 col2" >0.7801</td>
#       <td id="T_f01b0_row10_col3" class="data row10 col3" >0.7794</td>
#       <td id="T_f01b0_row10_col4" class="data row10 col4" >0.7776</td>
#       <td id="T_f01b0_row10_col5" class="data row10 col5" >0.5381</td>
#       <td id="T_f01b0_row10_col6" class="data row10 col6" >0.5413</td>
#     </tr>
#     <tr>
#       <th id="T_f01b0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f01b0_row11_col0" class="data row11 col0" >0.0256</td>
#       <td id="T_f01b0_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_f01b0_row11_col2" class="data row11 col2" >0.0256</td>
#       <td id="T_f01b0_row11_col3" class="data row11 col3" >0.0261</td>
#       <td id="T_f01b0_row11_col4
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr = cls.create_model('lr')
lr
# Out:
# <style type="text/css">
# #T_b1030_row10_col0, #T_b1030_row10_col1, #T_b1030_row10_col2, #T_b1030_row10_col3, #T_b1030_row10_col4, #T_b1030_row10_col5, #T_b1030_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b1030">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1030_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b1030_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b1030_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b1030_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b1030_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b1030_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b1030_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1030_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1030_row0_col0" class="data row0 col0" >0.7927</td>
#       <td id="T_b1030_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_b1030_row0_col2" class="data row0 col2" >0.7927</td>
#       <td id="T_b1030_row0_col3" class="data row0 col3" >0.8014</td>
#       <td id="T_b1030_row0_col4" class="data row0 col4" >0.7941</td>
#       <td id="T_b1030_row0_col5" class="data row0 col5" >0.5819</td>
#       <td id="T_b1030_row0_col6" class="data row0 col6" >0.5863</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1030_row1_col0" class="data row1 col0" >0.8049</td>
#       <td id="T_b1030_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_b1030_row1_col2" class="data row1 col2" >0.8049</td>
#       <td id="T_b1030_row1_col3" class="data row1 col3" >0.8045</td>
#       <td id="T_b1030_row1_col4" class="data row1 col4" >0.8027</td>
#       <td id="T_b1030_row1_col5" class="data row1 col5" >0.5910</td>
#       <td id="T_b1030_row1_col6" class="data row1 col6" >0.5941</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1030_row2_col0" class="data row2 col0" >0.7561</td>
#       <td id="T_b1030_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_b1030_row2_col2" class="data row2 col2" >0.7561</td>
#       <td id="T_b1030_row2_col3" class="data row2 col3" >0.7626</td>
#       <td id="T_b1030_row2_col4" class="data row2 col4" >0.7576</td>
#       <td id="T_b1030_row2_col5" class="data row2 col5" >0.5060</td>
#       <td id="T_b1030_row2_col6" class="data row2 col6" >0.5085</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1030_row3_col0" class="data row3 col0" >0.7439</td>
#       <td id="T_b1030_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_b1030_row3_col2" class="data row3 col2" >0.7439</td>
#       <td id="T_b1030_row3_col3" class="data row3 col3" >0.7451</td>
#       <td id="T_b1030_row3_col4" class="data row3 col4" >0.7444</td>
#       <td id="T_b1030_row3_col5" class="data row3 col5" >0.4747</td>
#       <td id="T_b1030_row3_col6" class="data row3 col6" >0.4748</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1030_row4_col0" class="data row4 col0" >0.7407</td>
#       <td id="T_b1030_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_b1030_row4_col2" class="data row4 col2" >0.7407</td>
#       <td id="T_b1030_row4_col3" class="data row4 col3" >0.7421</td>
#       <td id="T_b1030_row4_col4" class="data row4 col4" >0.7413</td>
#       <td id="T_b1030_row4_col5" class="data row4 col5" >0.4656</td>
#       <td id="T_b1030_row4_col6" class="data row4 col6" >0.4657</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1030_row5_col0" class="data row5 col0" >0.7284</td>
#       <td id="T_b1030_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_b1030_row5_col2" class="data row5 col2" >0.7284</td>
#       <td id="T_b1030_row5_col3" class="data row5 col3" >0.7548</td>
#       <td id="T_b1030_row5_col4" class="data row5 col4" >0.7305</td>
#       <td id="T_b1030_row5_col5" class="data row5 col5" >0.4629</td>
#       <td id="T_b1030_row5_col6" class="data row5 col6" >0.4774</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1030_row6_col0" class="data row6 col0" >0.7778</td>
#       <td id="T_b1030_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_b1030_row6_col2" class="data row6 col2" >0.7778</td>
#       <td id="T_b1030_row6_col3" class="data row6 col3" >0.7778</td>
#       <td id="T_b1030_row6_col4" class="data row6 col4" >0.7778</td>
#       <td id="T_b1030_row6_col5" class="data row6 col5" >0.5398</td>
#       <td id="T_b1030_row6_col6" class="data row6 col6" >0.5398</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1030_row7_col0" class="data row7 col0" >0.8148</td>
#       <td id="T_b1030_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_b1030_row7_col2" class="data row7 col2" >0.8148</td>
#       <td id="T_b1030_row7_col3" class="data row7 col3" >0.8191</td>
#       <td id="T_b1030_row7_col4" class="data row7 col4" >0.8159</td>
#       <td id="T_b1030_row7_col5" class="data row7 col5" >0.6218</td>
#       <td id="T_b1030_row7_col6" class="data row7 col6" >0.6236</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1030_row8_col0" class="data row8 col0" >0.8395</td>
#       <td id="T_b1030_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_b1030_row8_col2" class="data row8 col2" >0.8395</td>
#       <td id="T_b1030_row8_col3" class="data row8 col3" >0.8436</td>
#       <td id="T_b1030_row8_col4" class="data row8 col4" >0.8404</td>
#       <td id="T_b1030_row8_col5" class="data row8 col5" >0.6723</td>
#       <td id="T_b1030_row8_col6" class="data row8 col6" >0.6742</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1030_row9_col0" class="data row9 col0" >0.7901</td>
#       <td id="T_b1030_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_b1030_row9_col2" class="data row9 col2" >0.7901</td>
#       <td id="T_b1030_row9_col3" class="data row9 col3" >0.7987</td>
#       <td id="T_b1030_row9_col4" class="data row9 col4" >0.7914</td>
#       <td id="T_b1030_row9_col5" class="data row9 col5" >0.5777</td>
#       <td id="T_b1030_row9_col6" class="data row9 col6" >0.5822</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b1030_row10_col0" class="data row10 col0" >0.7789</td>
#       <td id="T_b1030_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_b1030_row10_col2" class="data row10 col2" >0.7789</td>
#       <td id="T_b1030_row10_col3" class="data row10 col3" >0.7850</td>
#       <td id="T_b1030_row10_col4" class="data row10 col4" >0.7796</td>
#       <td id="T_b1030_row10_col5" class="data row10 col5" >0.5494</td>
#       <td id="T_b1030_row10_col6" class="data row10 col6" >0.5527</td>
#     </tr>
#     <tr>
#       <th id="T_b1030_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b1030_row11_col0" class="data row11 col0" >0.0342</td>
#       <td id="T_b1030_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_b1030_row11_col2" class="data row11 col2" >0.0342</td>
#       <td id="T_b1030_row11_col3" class="data row11 col3" >0.0321</td>
#       <td id="T_b1030_row11_col4
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
tune_lr=tune_model(lr)
# Out:
# <style type="text/css">
# #T_e13bd_row10_col0, #T_e13bd_row10_col1, #T_e13bd_row10_col2, #T_e13bd_row10_col3, #T_e13bd_row10_col4, #T_e13bd_row10_col5, #T_e13bd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e13bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e13bd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e13bd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e13bd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e13bd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e13bd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e13bd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e13bd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e13bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e13bd_row0_col0" class="data row0 col0" >0.8049</td>
#       <td id="T_e13bd_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_e13bd_row0_col2" class="data row0 col2" >0.8049</td>
#       <td id="T_e13bd_row0_col3" class="data row0 col3" >0.8111</td>
#       <td id="T_e13bd_row0_col4" class="data row0 col4" >0.8061</td>
#       <td id="T_e13bd_row0_col5" class="data row0 col5" >0.6048</td>
#       <td id="T_e13bd_row0_col6" class="data row0 col6" >0.6078</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e13bd_row1_col0" class="data row1 col0" >0.8049</td>
#       <td id="T_e13bd_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_e13bd_row1_col2" class="data row1 col2" >0.8049</td>
#       <td id="T_e13bd_row1_col3" class="data row1 col3" >0.8045</td>
#       <td id="T_e13bd_row1_col4" class="data row1 col4" >0.8027</td>
#       <td id="T_e13bd_row1_col5" class="data row1 col5" >0.5910</td>
#       <td id="T_e13bd_row1_col6" class="data row1 col6" >0.5941</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e13bd_row2_col0" class="data row2 col0" >0.7805</td>
#       <td id="T_e13bd_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_e13bd_row2_col2" class="data row2 col2" >0.7805</td>
#       <td id="T_e13bd_row2_col3" class="data row2 col3" >0.7868</td>
#       <td id="T_e13bd_row2_col4" class="data row2 col4" >0.7818</td>
#       <td id="T_e13bd_row2_col5" class="data row2 col5" >0.5554</td>
#       <td id="T_e13bd_row2_col6" class="data row2 col6" >0.5582</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e13bd_row3_col0" class="data row3 col0" >0.7439</td>
#       <td id="T_e13bd_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_e13bd_row3_col2" class="data row3 col2" >0.7439</td>
#       <td id="T_e13bd_row3_col3" class="data row3 col3" >0.7451</td>
#       <td id="T_e13bd_row3_col4" class="data row3 col4" >0.7444</td>
#       <td id="T_e13bd_row3_col5" class="data row3 col5" >0.4747</td>
#       <td id="T_e13bd_row3_col6" class="data row3 col6" >0.4748</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e13bd_row4_col0" class="data row4 col0" >0.7284</td>
#       <td id="T_e13bd_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_e13bd_row4_col2" class="data row4 col2" >0.7284</td>
#       <td id="T_e13bd_row4_col3" class="data row4 col3" >0.7315</td>
#       <td id="T_e13bd_row4_col4" class="data row4 col4" >0.7295</td>
#       <td id="T_e13bd_row4_col5" class="data row4 col5" >0.4428</td>
#       <td id="T_e13bd_row4_col6" class="data row4 col6" >0.4433</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e13bd_row5_col0" class="data row5 col0" >0.7407</td>
#       <td id="T_e13bd_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_e13bd_row5_col2" class="data row5 col2" >0.7407</td>
#       <td id="T_e13bd_row5_col3" class="data row5 col3" >0.7633</td>
#       <td id="T_e13bd_row5_col4" class="data row5 col4" >0.7429</td>
#       <td id="T_e13bd_row5_col5" class="data row5 col5" >0.4850</td>
#       <td id="T_e13bd_row5_col6" class="data row5 col6" >0.4973</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e13bd_row6_col0" class="data row6 col0" >0.7778</td>
#       <td id="T_e13bd_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_e13bd_row6_col2" class="data row6 col2" >0.7778</td>
#       <td id="T_e13bd_row6_col3" class="data row6 col3" >0.7805</td>
#       <td id="T_e13bd_row6_col4" class="data row6 col4" >0.7787</td>
#       <td id="T_e13bd_row6_col5" class="data row6 col5" >0.5441</td>
#       <td id="T_e13bd_row6_col6" class="data row6 col6" >0.5448</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e13bd_row7_col0" class="data row7 col0" >0.8272</td>
#       <td id="T_e13bd_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_e13bd_row7_col2" class="data row7 col2" >0.8272</td>
#       <td id="T_e13bd_row7_col3" class="data row7 col3" >0.8296</td>
#       <td id="T_e13bd_row7_col4" class="data row7 col4" >0.8279</td>
#       <td id="T_e13bd_row7_col5" class="data row7 col5" >0.6454</td>
#       <td id="T_e13bd_row7_col6" class="data row7 col6" >0.6462</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e13bd_row8_col0" class="data row8 col0" >0.8642</td>
#       <td id="T_e13bd_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_e13bd_row8_col2" class="data row8 col2" >0.8642</td>
#       <td id="T_e13bd_row8_col3" class="data row8 col3" >0.8729</td>
#       <td id="T_e13bd_row8_col4" class="data row8 col4" >0.8652</td>
#       <td id="T_e13bd_row8_col5" class="data row8 col5" >0.7253</td>
#       <td id="T_e13bd_row8_col6" class="data row8 col6" >0.7310</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e13bd_row9_col0" class="data row9 col0" >0.7778</td>
#       <td id="T_e13bd_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_e13bd_row9_col2" class="data row9 col2" >0.7778</td>
#       <td id="T_e13bd_row9_col3" class="data row9 col3" >0.7840</td>
#       <td id="T_e13bd_row9_col4" class="data row9 col4" >0.7790</td>
#       <td id="T_e13bd_row9_col5" class="data row9 col5" >0.5511</td>
#       <td id="T_e13bd_row9_col6" class="data row9 col6" >0.5539</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e13bd_row10_col0" class="data row10 col0" >0.7850</td>
#       <td id="T_e13bd_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_e13bd_row10_col2" class="data row10 col2" >0.7850</td>
#       <td id="T_e13bd_row10_col3" class="data row10 col3" >0.7909</td>
#       <td id="T_e13bd_row10_col4" class="data row10 col4" >0.7858</td>
#       <td id="T_e13bd_row10_col5" class="data row10 col5" >0.5620</td>
#       <td id="T_e13bd_row10_col6" class="data row10 col6" >0.5651</td>
#     </tr>
#     <tr>
#       <th id="T_e13bd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e13bd_row11_col0" class="data row11 col0" >0.0398</td>
#       <td id="T_e13bd_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_e13bd_row11_col2" class="data row11 col2" >0.0398</td>
#       <td id="T_e13bd_row11_col3" class="data row11 col3" >0.0392</td>
#       <td id="T_e13bd_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
final_lr = finalize_model(tune_lr)
final_lr
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Year', 'Has FB',
#                                              'Backed Projects',
#                                              'Previous Projects',
#                                              'Creator Desc Len', 'Title Len',
#                                              'Goal', 'Duration',
#                                              'Pledge Levels',
#                                              'Min Pledge Tiers',
#                                              'Max Pledge T...
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                 ('actual_estimator',
#                  LogisticRegression(C=8.426, class_weight='balanced',
#                                     dual=False, fit_intercept=True,
#                                     intercept_scaling=1, l1_ratio=None,
#                                     max_iter=1000, multi_class='auto',
#                                     n_jobs=None, penalty='l2', random_state=42,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# We will save and use this  ***'final_lr'*** to predict the unseen data that will be imported below.

# %%
save_model(final_lr, './models/lr_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Year', 'Has FB',
#                                               'Backed Projects',
#                                               'Previous Projects',
#                                               'Creator Desc Len', 'Title Len',
#                                               'Goal', 'Duration',
#                                               'Pledge Levels',
#                                               'Min Pledge Tiers',
#                                               'Max Pledge T...
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('actual_estimator',
#                   LogisticRegression(C=8.426, class_weight='balanced',
#                                      dual=False, fit_intercept=True,
#                                      intercept_scaling=1, l1_ratio=None,
#                                      max_iter=1000, multi_class='auto',
#                                      n_jobs=None, penalty='l2', random_state=42,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  './models/lr_model.pkl')

# %% [markdown]
# #### **4.** Forth, we run the test against *unseen_data* and report on predictions and scores

# %%
unseen = pd.read_csv('./data/unseen_data.csv')
unseen.tail(3)
# Out:
#     Funded                                                URL  \
# 230     no  https://www.kickstarter.com/projects/330311462...
# 231     no  https://www.kickstarter.com/projects/853681317...
# 232    yes  https://www.kickstarter.com/projects/901324798...
#
#                                                  Title  Year Month      Type  \
# 230                                      PlastaPrint3D  2016   Mar    Design
# 231  SolidProjection SolidWorks to Unity3D with Sub...  2016   Mar  Software
# 232                                           Penitent  2016   Apr     Video
#
#      Has FB  Backed Projects  Previous Projects  Creator Desc Len  Title Len  \
# 230       0                0                  0               510         13
# 231       0                0                  0               488         60
# 232       1                2                  2               507          8
#
#          Goal  Duration  Pledge Levels  Min Pledge Tiers  Max Pledge Tiers  \
# 230  16977.52        30             13               6.0            3086.0
# 231    766.25        30              5             151.0             151.0
# 232   1200.00        10              6              10.0             500.0
#
#      Proj Desc Len  Images  Videos  Has Video
# 230           2422       8       2          1
# 231           1395       0       1          1
# 232           3206       0       1          1

# %%
unseen.shape
# Out:
# (233, 20)

# %%
import joblib
import pandas as pd

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
#from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_percentage_error

test = pd.read_csv('./data/unseen_data.csv')
test.shape
# Out:
# (233, 20)

# %%
cls = joblib.load('./models/lr_model.pkl')

# %%
### Test against the Unseen ###
unseen_X = test.drop('Funded', axis=1)
y = test['Funded']

# %%
y_pred = cls.predict(unseen_X)

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.88      0.82      0.85       139
#          yes       0.76      0.84      0.80        94
#
#     accuracy                           0.83       233
#    macro avg       0.82      0.83      0.82       233
# weighted avg       0.83      0.83      0.83       233

# %%
### to be able to encode the classification report we can import get_metrics()

# %%
from pycaret.classification import *

# %%
get_metrics()
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc          <function accuracy_score at 0x0000019C7BA86980>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa      <function cohen_kappa_score at 0x0000019C7BA86...
# mcc        <function matthews_corrcoef at 0x0000019C7BA86...
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# auc        make_scorer(roc_auc_score, response_method='pr...  pred_proba
# recall     make_scorer(recall_score, response_method='pre...        pred
# precision  make_scorer(precision_score, response_method='...        pred
# f1         make_scorer(f1_score, response_method='predict...        pred
# kappa      make_scorer(cohen_kappa_score, response_method...        pred
# mcc        make_scorer(matthews_corrcoef, response_method...        pred
#
#                                                     Args  Greater is Better  \
# ID
# acc                                                   {}               True
# auc        {'average': 'weighted', 'multi_class': 'ovr'}               True
# recall                           {'average': 'weighted'}               True
# precision                        {'average': 'weighted'}               True
# f1                               {'average': 'weighted'}               True
# kappa                                                 {}               True
# mcc                                                   {}               True
#
#            Multiclass  Custom
# ID
# acc              True   False
# auc              True   False
# recall           True   False
# precision        True   False
# f1               True   False
# kappa            True   False
# mcc              True   False

# %% [markdown]
# 1. **Accuracy**: This is the ratio of the number of correct predictions to the total number of predictions. It's used when the classes are balanced. It is calculated as:
#     $$\text{Accuracy} = \frac{\text{Number of Correct Predictions}}{\text{Total Number of Predictions}}$$
#
# 2. **AUC (Area Under the ROC Curve)**: This metric is used in binary classification. It measures the ability of the classifier to distinguish between classes. An AUC of 1 indicates a perfect classifier, while an AUC of 0.5 suggests a poor classifier.
#
# 3. **Recall (Sensitivity or True Positive Rate)**: This is the ratio of the number of true positives divided by the sum of the true positives and the false negatives. It shows how many of the positive samples have been identified correctly. It is calculated as:
#     $$\text{Recall} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Negatives}}$$
#
# 4. **Precision (Positive Predictive Value)**: This is the ratio of the number of true positives divided by the sum of the true positives and the false positives. It shows how many of the positively classified samples are actually positive. It is calculated as:
#     $$\text{Precision} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Positives}}$$
#
# 5. **F1 Score**: This is the harmonic mean of Precision and Recall and tries to balance the two. It is calculated as:
#     $$\text{F1 Score} = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# 6. **Kappa (Cohen's Kappa)**: This is used for multi-class classification. It measures the agreement between two raters who each classify items into mutually exclusive categories. A kappa of 1 indicates perfect agreement, while a kappa of 0 indicates agreement equivalent to chance.
#
# 7. **MCC (Matthews Correlation Coefficient)**: This is used in binary classification. It takes into account true and false positives and negatives and is generally regarded as a balanced measure which can be used even if the classes are of very different sizes. It is calculated as:
#     $$\text{MCC} = \frac{(\text{TP} \times \text{TN}) - (\text{FP} \times \text{FN})}{\sqrt{(\text{TP} + \text{FP})(\text{TP} + \text{FN})(\text{TN} + \text{FP})(\text{TN} + \text{FN})}}$$
#     where TP is True Positive, TN is True Negative, FP is False Positive, and FN is False Negative.
#
# These metrics provide a comprehensive view of the performance of a classification model. Different metrics are suitable for different scenarios and it's important to choose the right metric for the right task. For example, in a highly imbalanced dataset, accuracy might not be a good metric to use, and one might resort to using F1 Score, Precision, Recall, or AUC-ROC instead. Similarly, MCC is a good metric when the classes are of very different sizes.

# %%
df.dtypes == 'object'    #this is how we filter on in if we do == ''

# %%
df.dtypes == 'object'    #this is how we filter on in if we do == ''
# Out:
# Funded                True
# URL                   True
# Title                 True
# Year                 False
# Month                 True
# Type                  True
# Has FB               False
# Backed Projects      False
# Previous Projects    False
# Creator Desc Len     False
# Title Len            False
# Goal                 False
# Duration             False
# Pledge Levels        False
# Min Pledge Tiers     False
# Max Pledge Tiers     False
# Proj Desc Len        False
# Images               False
# Videos               False
# Has Video            False
# dtype: bool

# %%
df.dtypes != 'object'
# Out:
# Funded               False
# URL                  False
# Title                False
# Year                  True
# Month                False
# Type                 False
# Has FB                True
# Backed Projects       True
# Previous Projects     True
# Creator Desc Len      True
# Title Len             True
# Goal                  True
# Duration              True
# Pledge Levels         True
# Min Pledge Tiers      True
# Max Pledge Tiers      True
# Proj Desc Len         True
# Images                True
# Videos                True
# Has Video             True
# dtype: bool

# %%
df_numeric
# Out:
#       Year  Has FB  Backed Projects  Previous Projects  Creator Desc Len  \
# 0     2016       1               11                  2               125
# 2     2016       0                4                  0               294
# 3     2016       0                0                  0               179
# 5     2016       0                0                  0               162
# 6     2016       1                2                  0               110
# ...    ...     ...              ...                ...               ...
# 1156  2016       1                0                  0                55
# 1157  2016       0                0                  0                96
# 1158  2016       1                0                  0                53
# 1161  2016       0                2                  0               513
# 1162  2016       1                0                  4               253
#
#       Title Len       Goal  Duration  Pledge Levels  Min Pledge Tiers  \
# 0            57    2829.59        53              7              1.14
# 2            52     766.25        30              8              1.51
# 3            41    1439.10        24              5              7.00
# 5            30     800.00        28              1             10.00
# 6            55    2000.00        50              9              5.00
# ...         ...        ...       ...            ...               ...
# 1156         20   28295.87        40              6              5.00
# 1157         13   10000.00        60              1            100.00
# 1158          9  143909.50        30              2             14.00
# 1161         28    3831.25        60              2              0.71
# 1162         55   25000.00        30             14              1.00
#
#       Max Pledge Tiers  Proj Desc Len  Images  Videos  Has Video
# 0                171.0           2001       2       1          1
# 2                755.0           2325       1       1          1
# 3                141.0           3736      13       1          1
# 5                 10.0           1199       0       0          0
# 6                500.0           2384      11       0          0
# ...                ...            ...     ...     ...        ...
# 1156             546.0           4362      11       1          1
# 1157             100.0           2547       0       0          0
# 1158             143.0            508       0       0          0
# 1161             708.0            852       0       1          1
# 1162            5000.0           3738       0       0          0
#
# [930 rows x 15 columns]

# %%
# preprocess the data - create scaler...   
from sklearn.preprocessing import MinMaxScaler   
scaler = MinMaxScaler()

# %%
scaled_numeric = scaler.fit_transform(df_numeric)
scaled_numeric
# Out:
# array([[0.        , 1.        , 0.0316092 , ..., 0.02105263, 0.07692308,
#         1.        ],
#        [0.        , 0.        , 0.01149425, ..., 0.01052632, 0.07692308,
#         1.        ],
#        [0.        , 0.        , 0.        , ..., 0.13684211, 0.07692308,
#         1.        ],
#        ...,
#        [0.        , 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.00574713, ..., 0.        , 0.07692308,
#         1.        ],
#        [0.        , 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
scaled_numeric.shape     #only the numeric columns
# Out:
# (930, 15)

# %%
df_scaled_numeric = pd.DataFrame(scaled_numeric)
df_scaled_numeric.columns = df_numeric.columns
df_scaled_numeric
# Out:
#      Year  Has FB  Backed Projects  Previous Projects  Creator Desc Len  \
# 0     0.0     1.0         0.031609           0.068966          0.167336
# 1     0.0     0.0         0.011494           0.000000          0.393574
# 2     0.0     0.0         0.000000           0.000000          0.239625
# 3     0.0     0.0         0.000000           0.000000          0.216867
# 4     0.0     1.0         0.005747           0.000000          0.147256
# ..    ...     ...              ...                ...               ...
# 925   0.0     1.0         0.000000           0.000000          0.073628
# 926   0.0     0.0         0.000000           0.000000          0.128514
# 927   0.0     1.0         0.000000           0.000000          0.070950
# 928   0.0     0.0         0.005747           0.000000          0.686747
# 929   0.0     1.0         0.000000           0.137931          0.338688
#
#      Title Len      Goal  Duration  Pledge Levels  Min Pledge Tiers  \
# 0     0.691358  0.000281  0.844828       0.068182          0.000044
# 1     0.629630  0.000075  0.448276       0.079545          0.000081
# 2     0.493827  0.000142  0.344828       0.045455          0.000630
# 3     0.358025  0.000078  0.413793       0.000000          0.000930
# 4     0.666667  0.000198  0.793103       0.090909          0.000430
# ..         ...       ...       ...            ...               ...
# 925   0.234568  0.002828  0.620690       0.056818          0.000430
# 926   0.148148  0.000998  0.965517       0.000000          0.009931
# 927   0.098765  0.014389  0.448276       0.011364          0.001330
# 928   0.333333  0.000382  0.965517       0.011364          0.000001
# 929   0.666667  0.002498  0.448276       0.147727          0.000030
#
#      Max Pledge Tiers  Proj Desc Len    Images    Videos  Has Video
# 0            0.006810       0.068782  0.021053  0.076923        1.0
# 1            0.030171       0.080258  0.010526  0.076923        1.0
# 2            0.005610       0.130233  0.136842  0.076923        1.0
# 3            0.000370       0.040377  0.000000  0.000000        0.0
# 4            0.019970       0.082348  0.115789  0.000000        0.0
# ..                ...            ...       ...       ...        ...
# 925          0.021810       0.152405  0.115789  0.076923        1.0
# 926          0.003970       0.088121  0.000000  0.000000        0.0
# 927          0.005690       0.015903  0.000000  0.000000        0.0
# 928          0.028290       0.028087  0.000000  0.076923        1.0
# 929          0.199976       0.130304  0.000000  0.000000        0.0
#
# [930 rows x 15 columns]

# %% [markdown]
# ### Encode the DATA

# %%
#encode any text features that will be features (you do not encode Target / label/ y)
target = df_text['Funded']
df_text.drop(['Funded'], axis=1, inplace=True)

# %%
df_scaled_text = pd.get_dummies(df_text)     # dummies are ONE HOT ENCODING, specific variables
df_scaled_text
# Out:
#       URL_https://www.kickstarter.com/projects/1001163131/brandys-soy-candles  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1002686019/muros  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1005151588/my-first-horror-alphabet-book  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1005151588/the-little-abc-book-of-horror  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1007968674/artistic-collaboration-2016  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1008856355/crafts-and-jewelry-etsy-shop-start-up-by-jessilynn  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1009586486/slemish-woodcrafts  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1013189283/quicktask  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1013222245/serum-a-short-film  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       URL_https://www.kickstarter.com/projects/1015397918/cybersecurity-for-small-businesses  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 1156                                              False
# 1157                                              False
# 1158                                              False
# 1161                                              False
# 1162                                              False
#
#       ...  Month_Feb  Month_Mar  Month_May  Type_Apps  Type_Art  Type_Crafts  \
# 0     ...      False      False      False      False      True        False
# 2     ...      False      False      False      False      True        False
# 3     ...      False       True      False      False      True        False
# 5     ...      False       True      False      False      True        False
# 6     ...       True      False      False      False      True        False
# ...   ...        ...        ...        ...        ...       ...          ...
# 1156  ...      False       True      False      False     False        False
# 1157  ...       True      False      False      False     False        False
# 1158  ...      False       True      False      False     False        False
# 1161  ...       True      False      False      False     False        False
# 1162  ...      False       True      False      False     False        False
#
#       Type_Design  Type_Gadgets  Type_Software  Type_Video
# 0           False         False          False       False
# 2           False         False          False       False
# 3           False         False          False       False
# 5           False         False          False       False
# 6           False         False          False       False
# ...           ...           ...            ...         ...
# 1156        False         False           True       False
# 1157        False         False           True       False
# 1158        False         False           True       False
# 1161        False         False           True       False
# 1162        False         False           True       False
#
# [930 rows x 1871 columns]

# %%
df_final = pd.concat([df_scaled_text, df_scaled_numeric], axis=1)    #this is waht statistical algorithm wants to see in machine learning:
df_final
# Out:
#     URL_https://www.kickstarter.com/projects/1001163131/brandys-soy-candles  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1002686019/muros  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1005151588/my-first-horror-alphabet-book  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1005151588/the-little-abc-book-of-horror  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1007968674/artistic-collaboration-2016  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1008856355/crafts-and-jewelry-etsy-shop-start-up-by-jessilynn  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1009586486/slemish-woodcrafts  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1013189283/quicktask  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1013222245/serum-a-short-film  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#     URL_https://www.kickstarter.com/projects/1015397918/cybersecurity-for-small-businesses  \
# 0                                                False
# 2                                                False
# 3                                                False
# 5                                                False
# 6                                                False
# ..                                                 ...
# 904                                                NaN
# 907                                                NaN
# 912                                                NaN
# 925                                                NaN
# 926                                                NaN
#
#      ... Title Len      Goal  Duration Pledge Levels Min Pledge Tiers  \
# 0    ...  0.691358  0.000281  0.844828      0.068182         0.000044
# 2    ...  0.493827  0.000142  0.344828      0.045455         0.000630
# 3    ...  0.358025  0.000078  0.413793      0.000000         0.000930
# 5    ...  0.703704  0.000098  0.448276      0.022727         0.000030
# 6    ...  0.222222  0.000106  0.448276      0.170455         0.000630
# ..   ...       ...       ...       ...           ...              ...
# 904  ...  0.123457  0.000225  0.448276      0.056818         0.001030
# 907  ...  0.518519  1.000000  0.965517      0.000000         0.000030
# 912  ...  0.098765  0.003498  0.448276      0.056818         0.000930
# 925  ...  0.234568  0.002828  0.620690      0.056818         0.000430
# 926  ...  0.148148  0.000998  0.965517      0.000000         0.009931
#
#     Max Pledge Tiers Proj Desc Len    Images    Videos Has Video
# 0            0.00681      0.068782  0.021053  0.076923       1.0
# 2            0.00561      0.130233  0.136842  0.076923       1.0
# 3            0.00037      0.040377  0.000000  0.000000       0.0
# 5            0.00117      0.054686  0.010526  0.076923       1.0
# 6            0.00625      0.082808  0.094737  0.076923       1.0
# ..               ...           ...       ...       ...       ...
# 904          0.00905      0.171247  0.052632  0.076923       1.0
# 907          0.00001      0.000000  0.000000  0.000000       0.0
# 912          0.00997      0.259616  0.000000  0.076923       1.0
# 925          0.02181      0.152405  0.115789  0.076923       1.0
# 926          0.00397      0.088121  0.000000  0.000000       0.0
#
# [1119 rows x 1886 columns]

# %% [markdown]
# ### Get the train model scores

# %%
y = target
y.shape, y.dtype
# Out:
# ((930,), dtype('O'))

# %%
y.value_counts()
# Out:
# Funded
# no     546
# yes    384
# Name: count, dtype: int64

# %%
X = df_final
X.head()
# Out:
#   URL_https://www.kickstarter.com/projects/1001163131/brandys-soy-candles  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1002686019/muros  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1005151588/my-first-horror-alphabet-book  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1005151588/the-little-abc-book-of-horror  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1007968674/artistic-collaboration-2016  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1008856355/crafts-and-jewelry-etsy-shop-start-up-by-jessilynn  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1009586486/slemish-woodcrafts  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1013189283/quicktask  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1013222245/serum-a-short-film  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#   URL_https://www.kickstarter.com/projects/1015397918/cybersecurity-for-small-businesses  \
# 0                                              False
# 2                                              False
# 3                                              False
# 5                                              False
# 6                                              False
#
#    ... Title Len      Goal  Duration Pledge Levels Min Pledge Tiers  \
# 0  ...  0.691358  0.000281  0.844828      0.068182         0.000044
# 2  ...  0.493827  0.000142  0.344828      0.045455         0.000630
# 3  ...  0.358025  0.000078  0.413793      0.000000         0.000930
# 5  ...  0.703704  0.000098  0.448276      0.022727         0.000030
# 6  ...  0.222222  0.000106  0.448276      0.170455         0.000630
#
#   Max Pledge Tiers Proj Desc Len    Images    Videos Has Video
# 0          0.00681      0.068782  0.021053  0.076923       1.0
# 2          0.00561      0.130233  0.136842  0.076923       1.0
# 3          0.00037      0.040377  0.000000  0.000000       0.0
# 5          0.00117      0.054686  0.010526  0.076923       1.0
# 6          0.00625      0.082808  0.094737  0.076923       1.0
#
# [5 rows x 1886 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)
#
# File ~\miniconda3\envs\pc311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\miniconda3\envs\pc311\Lib\site-packages\sklearn\model_selection\_split.py:2657, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2654 if n_arrays == 0:
#    2655     raise ValueError("At least one array required as input")
# -> 2657 arrays = indexable(*arrays)
#    2659 n_samples = _num_samples(arrays[0])
#    2660 n_train, n_test = _validate_shuffle_split(
#    2661     n_samples, test_size, train_size, default_test_size=0.25
#    2662 )
#
# File ~\miniconda3\envs\pc311\Lib\site-packages\sklearn\utils\validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File ~\miniconda3\envs\pc311\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1119, 930]

# %%
X_train[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 X_train[0:5]
#
# NameError: name 'X_train' is not defined

# %%
X_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 X_test.head()
#
# NameError: name 'X_test' is not defined

# %%
y_train.head()

# %%
y_test.head()

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
lgr = LogisticRegression()

# %%
lgr.fit(X_train, y_train)

# %%
lgr_preds_train = lgr.predict(X_train)

# %%
lgr.score(X_train, y_train)

# %%
lgr_cm = confusion_matrix(lgr_preds_train, y_train)
lgr_cm

# %%
sns.heatmap(lgr_cm, annot=True, fmt='d')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [raw]
# acc = accuracy_score(pred['actual_label'], pred['prediction_label'])
# prec = precision_score(pred['actual_label'], pred['prediction_label'], average='weighted')
# rec = recall_score(pred['actual_label'], pred['prediction_label'], average='weighted')

# %% [raw]
# print(f'Accuracy: {acc}\nPrecision: {prec}\nRecall: {rec}')

# %% [raw]
# cm = confusion_matrix(pred['actual_label'], pred['prediction_label'])
# cm

# %%
#import seaborn as sns

# %% [raw]
# sns.heatmap(cm, annot=True, cmap='flare');    #if you wanna change colors go to seamaps, get pallets

# %%
from sklearn.metrics import classification_report
print(classification_report(X, y_pred))

# %% [markdown]
# ### BONUS 'TIP of a DAY'

# %% [markdown]
# #### Difference between predict. and predict.model()

# %%
from pycaret.classification import ClassificationExperiment
cls_oop = ClassificationExperiment()      # it is not real set up , but just an experiment itself

# %%
cls_oop

# %%
cls_oop.predict_model(final_lr, unseen)       #because this brings back whole dataframe, put it into df

# %%
# this is like 1 hot ecoding, it is original data with actual = Feedback and the predictive label that is predicted actual and pred scores

# %%
df_oop = cls_oop.predict_model(final_lr, unseen)

# %%
y_true = df_oop['Funded']
y_pred = df_oop['prediction_label']

# %%
#df_oop[df_oop['Feedback'] != df_oop['prediction_label']]   #look how the 99 had an 85% prediction score ti will be wirgh, but it still predicted wrong!

# %%
df_oop.sort_values(['prediction_score'])    #the whole enchilada

# %%
type(y_true.dtype), type(y_pred.dtype), y_true.dtype, y_pred.dtype, type(y_true[0]), type (y_pred[0])

# %%
cls_oop      #it returns classification experiment

# %% [markdown]
# ### FINDINGS

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cls = final_lr
unseen_X = unseen.drop('Funded', axis=1)
y_true = unseen['Funded']

# %%
y_pred = cls.predict(unseen_X)       # in the settings it does say it returns array
# y_true, y_pred # once you have pred_y and true_y you can go straigh to scoring

# %%
unseen_X.shape, y_pred.shape

# %% [raw]
# print(classification_report(y_true, y_pred))    # i had a stupid ) missing cause of print()

# %%
classification_report(unseen['Funded'], cls.predict(unseen_X))    # better output if print()

# %%
report = classification_report(y_true, y_pred)   #Shitf+Tab will show what it will show
print(report)

# %% [markdown]
# #### ALWAYS STOP AND LOOK AT WHAT YOU GET: STRING, OBJECT ECT...

# %%
y_true.dtype, y_pred.dtype  , #(y_true[0])    # mine and Jumanas pred_y was dataframe, where Pats was object

# %%
type(y_true[0]), type (y_pred[0])

# %%
type(y_true.dtype), type(y_pred.dtype)      # Pat's are numpy arrays

# %% [markdown]
# ## Functional API vs Object Oriented Programming (OOP) API

# %%
### With Object Oriented OOP we can run different experiments at same time, like in one we used balancing and on one didnt

# %% [raw]
# Functional API will load all data in memory into this function, like in the namespace, and everythime you call it it will refer to it

# %% [raw]
# in OOP instead putting all into the memory, it puts it into an OBJECT!!! so it has an extra step in set up, the "s", passing into the setup, you are performing coding against an object and getting a result!  = it is called INSTANTIATION, CLASS = classification experiment, (like a templete) and in the end we call Initializer = function

# %%
from pycaret.classification import ClassificationExperiment
s1 = ClassificationExperiment()      # it is not real set up , but just an experiment itself
s2 = ClassificationExperiment()
s1.setup(data, target='Funded', session_id=42, fix_imbalance=True);             # we can compare this 2 set up, with fix imbalance or not
s2.setup(data, target='Funded', session_id=42, fix_imbalance=False);

# %%
accuracy_score(y_true, y_pred)

# %%
precision_score(y_true, y_pred, pos_label='yes')

# %%
recall_score(y_true, y_pred, pos_label='yes')

# %%
cm = confusion_matrix(y_true, y_pred)
cm

# %%
ax = sns.heatmap(cm, annot=True, cmap='flare')    #all this has to be in the same cell and we take control of my axis
ax.set_xticklabels(['Negative', 'Positive'])
ax.set_xticklabels(['Negative', 'Positive'])
plt.xlabel('Predict Labels')
plt.ylabel('True Labels')
plt.title('Unseen Dataset Confusion Matrix')

# %%
# the way to test the results
df = pd.DataFrame({'Pred':y_pred, 'True':y_true})

# %%
# OOP API
kmeans = s.create_model('kmeans', num_clusters=4)

# %%
diff = df[df['Pred'] != df['True']]
diff['Pred'].value_counts()

# %%
from pycaret.classification import *
plot_model(lr, plot = 'class_report')

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique) is a type of DATA AUGEMENTATION TECHNIQUE

# %%
from pycaret.classification import setup, models, create_model, tune_model, finalize_model, save_model, evaluate_model
cls = setup(data, target='Funded', session_id=42, fix_imbalance=True, fix_imbalance_method= 'SMOTE')
